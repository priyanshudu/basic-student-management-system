# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshudu/basic-student-management-system/blob/main/working.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Imports
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Step 2: Load dataset
df = pd.read_csv('/content/Sustainable Development (Responses).csv.csv')  # Replace with your CSV path

# Step 3: Create binary target
df['target_binary'] = df['would you be willing to switch to eco-friendly transport'].apply(lambda x: 1 if x=='Yes' else 0)

# Step 4: Drop unnecessary columns
X = df.drop(['Timestamp', 'would you be willing to switch to eco-friendly transport', 'target_binary'], axis=1)
y = df['target_binary']

# Step 5: One-hot encode categorical variables
X_encoded = pd.get_dummies(X, drop_first=True)

# Step 6: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42, stratify=y)

# Step 7: Model
rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)

# Step 8: Predictions
y_pred = rf.predict(X_test)

# Step 9: Metrics
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Step 10: Feature Importances
importances = pd.Series(rf.feature_importances_, index=X_encoded.columns).sort_values(ascending=False)
print("\nTop Features:\n", importances.head(10))
# Out:
# Test Accuracy: 0.5853658536585366
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.81      0.71        26
#            1       0.38      0.20      0.26        15
#
#     accuracy                           0.59        41
#    macro avg       0.51      0.50      0.49        41
# weighted avg       0.54      0.59      0.55        41
#
#
# Confusion Matrix:
#  [[21  5]
#  [12  3]]
#
# Top Features:
#  what is your age _above 31                                                                     0.049986
# why would you switch to eco friendly transport _lack of awareness                              0.046103
# what is your main mode of transport_walking                                                    0.044585
# In a few words describe your view of sustainable transport_We need better public transport.    0.044413
# ...

# %%
# Import libraries
import pandas as pd

# Load dataset
file_path = "/content/Sustainable Development (Responses).csv.csv"  # <-- replace with your file path
df = pd.read_csv(file_path)

# Basic info
print("----- Dataset Info -----")
print(df.info())
print("\n----- Shape of Dataset -----")
print(df.shape)

# First few rows
print("\n----- First 5 Rows -----")
print(df.head())

# Check for missing values
print("\n----- Missing Values -----")
print(df.isnull().sum())

# Target distribution
target_col = "would you be willing to switch to eco-friendly transport"  # change if needed
print(f"\n----- Target ({target_col}) Distribution -----")
print(df[target_col].value_counts())

# Distribution for all categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()
for col in categorical_cols:
    if col != target_col:
        print(f"\n----- Distribution for {col} -----")
        print(df[col].value_counts())

# Unique values per column
print("\n----- Unique Values per Column -----")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")

# Cross-tab of categorical columns vs target
for col in categorical_cols:
    if col != target_col:
        print(f"\n----- Cross-tab: {col} vs {target_col} -----")
        print(pd.crosstab(df[col], df[target_col]))

# Optional: check if any numeric columns exist
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
if numeric_cols:
    print("\n----- Numeric Columns -----")
    print(df[numeric_cols].describe())
else:
    print("\nNo numeric columns found.")
# Out:
# ----- Dataset Info -----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 11 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Timestamp                                                   201 non-null    object
#  1   what is your age                                            201 non-null    object
#  2   what is your gender                                         201 non-null    object
#  3   have you heard about sustainable transport                  201 non-null    object
#  4   what is your main mode of transport                         201 non-null    object
#  5   how much distance do you travel on daily basis              201 non-null    object
#  6   how  often do you use public transport                      201 non-null    object
# ...

# %%
# Step 1: Imports
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Step 2: Load dataset
df = pd.read_excel('/content/Sustainable Development (Responses).csv.xlsx')  # Replace with your CSV path

# Step 3: Create binary target
df['target_binary'] = df['would you be willing to switch to eco-friendly transport'].apply(lambda x: 1 if x=='Yes' else 0)

# Step 4: Drop unnecessary columns
X = df.drop(['Timestamp', 'would you be willing to switch to eco-friendly transport', 'target_binary'], axis=1)
y = df['target_binary']

# Step 5: One-hot encode categorical variables
X_encoded = pd.get_dummies(X, drop_first=True)

# Step 6: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42, stratify=y)

# Step 7: Model
rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)

# Step 8: Predictions
y_pred = rf.predict(X_test)

# Step 9: Metrics
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Step 10: Feature Importances
importances = pd.Series(rf.feature_importances_, index=X_encoded.columns).sort_values(ascending=False)
print("\nTop Features:\n", importances.head(10))
# Out:
# Test Accuracy: 0.8518518518518519
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89        51
#            1       0.91      0.67      0.77        30
#
#     accuracy                           0.85        81
#    macro avg       0.87      0.81      0.83        81
# weighted avg       0.86      0.85      0.85        81
#
#
# Confusion Matrix:
#  [[49  2]
#  [10 20]]
#
# Top Features:
#  have you heard about sustainable transport _Yes                                                0.047781
# why would you switch to eco friendly transport _lack of awareness                              0.047312
# what is your age _above 31                                                                     0.045618
# how  often do you use public transport _never                                                  0.042788
# ...

# %%
# Import libraries
import pandas as pd

# Load dataset
file_path = "/content/Sustainable Development (Responses).csv.xlsx"  # <-- replace with your file path
df = pd.read_excel(file_path)

# Basic info
print("----- Dataset Info -----")
print(df.info())
print("\n----- Shape of Dataset -----")
print(df.shape)

# First few rows
print("\n----- First 5 Rows -----")
print(df.head())

# Check for missing values
print("\n----- Missing Values -----")
print(df.isnull().sum())

# Target distribution
target_col = "would you be willing to switch to eco-friendly transport"  # change if needed
print(f"\n----- Target ({target_col}) Distribution -----")
print(df[target_col].value_counts())

# Distribution for all categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()
for col in categorical_cols:
    if col != target_col:
        print(f"\n----- Distribution for {col} -----")
        print(df[col].value_counts())

# Unique values per column
print("\n----- Unique Values per Column -----")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")

# Cross-tab of categorical columns vs target
for col in categorical_cols:
    if col != target_col:
        print(f"\n----- Cross-tab: {col} vs {target_col} -----")
        print(pd.crosstab(df[col], df[target_col]))

# Optional: check if any numeric columns exist
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
if numeric_cols:
    print("\n----- Numeric Columns -----")
    print(df[numeric_cols].describe())
else:
    print("\nNo numeric columns found.")
# Out:
# ----- Dataset Info -----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 11 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Timestamp                                                   402 non-null    datetime64[ns]
#  1   what is your age                                            402 non-null    object
#  2   what is your gender                                         402 non-null    object
#  3   have you heard about sustainable transport                  402 non-null    object
#  4   what is your main mode of transport                         402 non-null    object
#  5   how much distance do you travel on daily basis              402 non-null    object
#  6   how  often do you use public transport                      402 non-null    object
# ...

# %%
# Import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Load dataset
df = pd.read_excel('/content/Sustainable Development (Responses).csv.xlsx')  # replace with your file path

# Convert target to binary: Yes vs No/Maybe
df['target'] = df['would you be willing to switch to eco-friendly transport'].apply(
    lambda x: 'Yes' if x=='Yes' else 'No'
)

# Drop Timestamp and original target
X = df.drop(['Timestamp','would you be willing to switch to eco-friendly transport','target'], axis=1)
y = df['target']

# One-hot encode categorical features
X_encoded = pd.get_dummies(X, drop_first=True)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42, stratify=y
)

# Initialize Random Forest
rf = RandomForestClassifier(n_estimators=200, max_depth=9, random_state=42)

# Train model
rf.fit(X_train, y_train)

# Predictions
y_pred = rf.predict(X_test)

# Evaluation
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Feature importance
feat_imp = pd.Series(rf.feature_importances_, index=X_encoded.columns)
feat_imp = feat_imp.sort_values(ascending=False)
print("\nTop Features:\n", feat_imp.head(10))
# Out:
# Test Accuracy: 0.9012345679012346
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           No       0.86      1.00      0.93        51
#          Yes       1.00      0.73      0.85        30
#
#     accuracy                           0.90        81
#    macro avg       0.93      0.87      0.89        81
# weighted avg       0.91      0.90      0.90        81
#
# Confusion Matrix:
#  [[51  0]
#  [ 8 22]]
#
# Top Features:
#  why would you switch to eco friendly transport _lack of awareness                              0.051382
# have you heard about sustainable transport _Yes                                                0.044756
# what is your age _above 31                                                                     0.044573
# how  often do you use public transport _never                                                  0.041824
# what is your gender_Prefer not to say                                                          0.041714
# ...

# %%
from sklearn.linear_model import LogisticRegression

# Initialize Logistic Regression
lr = LogisticRegression(max_iter=500, random_state=42)

# Train
lr.fit(X_train, y_train)

# Predict
y_pred_lr = lr.predict(X_test)

# Evaluation
print("Logistic Regression Test Accuracy:", accuracy_score(y_test, y_pred_lr))
print("\nClassification Report:\n", classification_report(y_test, y_pred_lr))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_lr))
# Out:
# Logistic Regression Test Accuracy: 0.5185185185185185
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           No       0.60      0.71      0.65        51
#          Yes       0.29      0.20      0.24        30
#
#     accuracy                           0.52        81
#    macro avg       0.44      0.45      0.44        81
# weighted avg       0.48      0.52      0.50        81
#
# Confusion Matrix:
#  [[36 15]
#  [24  6]]

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize Decision Tree
dt = DecisionTreeClassifier(max_depth=9, random_state=42)

# Train
dt.fit(X_train, y_train)

# Predict
y_pred_dt = dt.predict(X_test)

# Evaluation
print("Decision Tree Test Accuracy:", accuracy_score(y_test, y_pred_dt))
print("\nClassification Report:\n", classification_report(y_test, y_pred_dt))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))

# Feature importance
feat_imp_dt = pd.Series(dt.feature_importances_, index=X_encoded.columns).sort_values(ascending=False)
print("\nTop Features (Decision Tree):\n", feat_imp_dt.head(10))
# Out:
# Decision Tree Test Accuracy: 0.8395061728395061
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           No       0.87      0.88      0.87        51
#          Yes       0.79      0.77      0.78        30
#
#     accuracy                           0.84        81
#    macro avg       0.83      0.82      0.83        81
# weighted avg       0.84      0.84      0.84        81
#
# Confusion Matrix:
#  [[45  6]
#  [ 7 23]]
#
# Top Features (Decision Tree):
#  what is your gender_Male                                                                0.133074
# how much distance do you travel on daily basis _above 20 km                             0.090650
# how should the government promote sustainable transport_subsidies /financial support    0.087031
# how  often do you use public transport _never                                           0.071877
# what is your age _above 31                                                              0.069157
# ...
